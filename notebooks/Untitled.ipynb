# %%
import os
import pandas as pd

# %%
df = pd.read_csv("../data/raw/ai4i2020.csv")

# %%
df.describe().T
# Out:
#                            count        mean         std     min     25%  \
# Air_temperature_[K]      10000.0   300.00493    2.000259   295.3   298.3
# Process_temperature_[K]  10000.0   310.00556    1.483734   305.7   308.8
# Rotational_speed_[rpm]   10000.0  1538.77610  179.284096  1168.0  1423.0
# Torque_[Nm]              10000.0    39.98691    9.968934     3.8    33.2
# Tool_wear_[min]          10000.0   107.95100   63.654147     0.0    53.0
# TWF                      10000.0     0.00460    0.067671     0.0     0.0
# HDF                      10000.0     0.01150    0.106625     0.0     0.0
# PWF                      10000.0     0.00950    0.097009     0.0     0.0
# OSF                      10000.0     0.00980    0.098514     0.0     0.0
# RNF                      10000.0     0.00190    0.043550     0.0     0.0
#
#                             50%     75%     max
# Air_temperature_[K]       300.1   301.5   304.5
# Process_temperature_[K]   310.1   311.1   313.8
# ...

# %%
overview = df.describe()

# %%
overview.loc[["min","max"]].to_json("schema_in.json")
